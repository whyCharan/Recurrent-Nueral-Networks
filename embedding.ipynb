# %%
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# WARNING:tensorflow:From c:\Users\chara\anaconda3\envs\DLenv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
### SEntences

sent = [
    'The glass of milk',
    'The glass of Juice',
    'The cup of tea',
    'I am a good boy',
    'I am a good developer',
    'I am a good developer',
    'Understand the meaning of words',
    'Your videos are good',
]

# %%
sent
# Out:
# ['The glass of milk',
#  'The glass of Juice',
#  'The cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'I am a good developer',
#  'Understand the meaning of words',
#  'Your videos are good']

# %%
## Define the vocabulary words

voc_size = 10000

# %%
## One hot Representation

one_hot_repre = [one_hot(words,voc_size) for words in sent]
one_hot_repre
# Out:
# [[8333, 1381, 2415, 1189],
#  [8333, 1381, 2415, 9711],
#  [8333, 8908, 2415, 4580],
#  [7024, 5933, 2152, 9777, 5855],
#  [7024, 5933, 2152, 9777, 4114],
#  [7024, 5933, 2152, 9777, 4114],
#  [3235, 8333, 6056, 2415, 7484],
#  [3336, 959, 1162, 9777]]

# %%
## word  embedding Representation

from tensorflow.keras.layers import Embedding
#from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length = 8 
embedded_docs = pad_sequences(one_hot_repre,padding='pre',maxlen=sent_length)
embedded_docs
# Out:
# array([[   0,    0,    0,    0, 8333, 1381, 2415, 1189],
#        [   0,    0,    0,    0, 8333, 1381, 2415, 9711],
#        [   0,    0,    0,    0, 8333, 8908, 2415, 4580],
#        [   0,    0,    0, 7024, 5933, 2152, 9777, 5855],
#        [   0,    0,    0, 7024, 5933, 2152, 9777, 4114],
#        [   0,    0,    0, 7024, 5933, 2152, 9777, 4114],
#        [   0,    0,    0, 3235, 8333, 6056, 2415, 7484],
#        [   0,    0,    0,    0, 3336,  959, 1162, 9777]])

# %%
# feature Representation

dim = 10

# %%
model = Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# WARNING:tensorflow:From c:\Users\chara\anaconda3\envs\DLenv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\chara\anaconda3\envs\DLenv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 409ms/step
# array([[[ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [-0.02508702,  0.01603602, -0.04701871, -0.0139125 ,
#          -0.00636628,  0.02163669,  0.01651229,  0.01357988,
#          -0.00096762, -0.01999525],
#         [-0.04091221,  0.03472464, -0.01130644,  0.0182649 ,
#           0.00739504, -0.04004062,  0.04716447, -0.03073124,
#           0.00784934, -0.02733555],
#         [-0.02141132,  0.00792418, -0.0459176 , -0.01434652,
#          -0.02570109,  0.03223789,  0.00888991,  0.0345226 ,
#          -0.03853131, -0.03417619],
#         [-0.04122189,  0.02261614, -0.00722284, -0.02436062,
#           0.01109809,  0.00863735, -0.01335945,  0.03298558,
#          -0.02983972,  0.00294145]],
#
#        [[ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [-0.02508702,  0.01603602, -0.04701871, -0.0139125 ,
#          -0.00636628,  0.02163669,  0.01651229,  0.01357988,
#          -0.00096762, -0.01999525],
#         [-0.04091221,  0.03472464, -0.01130644,  0.0182649 ,
#           0.00739504, -0.04004062,  0.04716447, -0.03073124,
#           0.00784934, -0.02733555],
#         [-0.02141132,  0.00792418, -0.0459176 , -0.01434652,
#          -0.02570109,  0.03223789,  0.00888991,  0.0345226 ,
#          -0.03853131, -0.03417619],
#         [ 0.00073317,  0.01279565,  0.01781983,  0.01925879,
#           0.03059084, -0.03912257,  0.03452339, -0.01413018,
#          -0.04742799, -0.01196356]],
#
#        [[ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [-0.02508702,  0.01603602, -0.04701871, -0.0139125 ,
#          -0.00636628,  0.02163669,  0.01651229,  0.01357988,
#          -0.00096762, -0.01999525],
#         [ 0.00062539,  0.04052335,  0.04302337, -0.02293324,
#           0.02575381, -0.04761785, -0.00598975,  0.03527943,
#          -0.0364634 ,  0.03557966],
#         [-0.02141132,  0.00792418, -0.0459176 , -0.01434652,
#          -0.02570109,  0.03223789,  0.00888991,  0.0345226 ,
#          -0.03853131, -0.03417619],
#         [-0.01306411, -0.00764706, -0.04059337, -0.01181763,
#           0.03213613,  0.0408432 , -0.00434514, -0.01068748,
#           0.03149856,  0.03460113]],
#
#        [[ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.02544351,  0.01633573, -0.03639696,  0.03368448,
#           0.00614103, -0.01651869, -0.01526843, -0.02977741,
#           0.01564827, -0.02048532],
#         [-0.04782123,  0.02125959,  0.03878455,  0.03238905,
#           0.04943588,  0.04504395, -0.0343341 ,  0.04859897,
#          -0.00785413, -0.00887682],
#         [-0.0299407 ,  0.04852306,  0.01823941, -0.01127516,
#          -0.00758906,  0.04499353,  0.00041796, -0.00691056,
#          -0.01509108,  0.04556478],
#         [ 0.02872154, -0.01308091,  0.03945068, -0.04696209,
#           0.026999  ,  0.03715766,  0.01765494,  0.04578548,
#           0.01805414, -0.01483776],
#         [-0.00914354, -0.03750888,  0.03793791,  0.03276828,
#           0.00862388, -0.02711501,  0.02987948,  0.0203597 ,
#           0.03358437, -0.00377146]],
#
#        [[ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.02544351,  0.01633573, -0.03639696,  0.03368448,
#           0.00614103, -0.01651869, -0.01526843, -0.02977741,
#           0.01564827, -0.02048532],
#         [-0.04782123,  0.02125959,  0.03878455,  0.03238905,
#           0.04943588,  0.04504395, -0.0343341 ,  0.04859897,
#          -0.00785413, -0.00887682],
#         [-0.0299407 ,  0.04852306,  0.01823941, -0.01127516,
#          -0.00758906,  0.04499353,  0.00041796, -0.00691056,
#          -0.01509108,  0.04556478],
#         [ 0.02872154, -0.01308091,  0.03945068, -0.04696209,
#           0.026999  ,  0.03715766,  0.01765494,  0.04578548,
#           0.01805414, -0.01483776],
#         [-0.00227814, -0.04456058, -0.04542645,  0.0134953 ,
#          -0.04678318,  0.02309659,  0.04483724, -0.04815085,
#          -0.02495971, -0.03571198]],
#
#        [[ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.02544351,  0.01633573, -0.03639696,  0.03368448,
#           0.00614103, -0.01651869, -0.01526843, -0.02977741,
#           0.01564827, -0.02048532],
#         [-0.04782123,  0.02125959,  0.03878455,  0.03238905,
#           0.04943588,  0.04504395, -0.0343341 ,  0.04859897,
#          -0.00785413, -0.00887682],
#         [-0.0299407 ,  0.04852306,  0.01823941, -0.01127516,
#          -0.00758906,  0.04499353,  0.00041796, -0.00691056,
#          -0.01509108,  0.04556478],
#         [ 0.02872154, -0.01308091,  0.03945068, -0.04696209,
#           0.026999  ,  0.03715766,  0.01765494,  0.04578548,
#           0.01805414, -0.01483776],
#         [-0.00227814, -0.04456058, -0.04542645,  0.0134953 ,
#          -0.04678318,  0.02309659,  0.04483724, -0.04815085,
#          -0.02495971, -0.03571198]],
#
#        [[ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [-0.00765929,  0.0270029 , -0.02499831,  0.02169206,
#          -0.01738548, -0.01507109, -0.04015166, -0.01212232,
#           0.03663058, -0.01880118],
#         [-0.02508702,  0.01603602, -0.04701871, -0.0139125 ,
#          -0.00636628,  0.02163669,  0.01651229,  0.01357988,
#          -0.00096762, -0.01999525],
#         [-0.03027576,  0.01570084, -0.00398836, -0.01413857,
#          -0.01556545,  0.04245936,  0.00403104,  0.03426773,
#          -0.02010443,  0.00271578],
#         [-0.02141132,  0.00792418, -0.0459176 , -0.01434652,
#          -0.02570109,  0.03223789,  0.00888991,  0.0345226 ,
#          -0.03853131, -0.03417619],
#         [-0.01066057, -0.03563837, -0.02124791, -0.01619142,
#           0.04025752,  0.01823634, -0.02635582,  0.02260924,
#          -0.01970432, -0.02067474]],
#
#        [[ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.03044024,  0.02006564,  0.00015533,  0.009558  ,
#          -0.03660792,  0.03212324,  0.02074495, -0.01172236,
#          -0.01358556, -0.04511023],
#         [ 0.02605548, -0.03576343, -0.03131576, -0.01178991,
#          -0.00131663,  0.0027658 ,  0.04956916,  0.04556068,
#          -0.00526688, -0.04477645],
#         [-0.04578315,  0.0078989 , -0.01064706,  0.02364503,
#          -0.04850766,  0.0388403 ,  0.00907231, -0.0367372 ,
#           0.01988348, -0.0482691 ],
#         [ 0.02379045,  0.03709681,  0.04707367, -0.03878165,
#          -0.00843433, -0.01812229,  0.02791281,  0.03093458,
#          -0.04196392, -0.00209748],
#         [ 0.02872154, -0.01308091,  0.03945068, -0.04696209,
#           0.026999  ,  0.03715766,  0.01765494,  0.04578548,
#           0.01805414, -0.01483776]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 8333, 1381, 2415, 1189])

# %%
model.predict(embedded_docs[0])
# Out:
# 1/1 [==============================] - 0s 110ms/step
# array([[ 0.03044024,  0.02006564,  0.00015533,  0.009558  , -0.03660792,
#          0.03212324,  0.02074495, -0.01172236, -0.01358556, -0.04511023],
#        [ 0.03044024,  0.02006564,  0.00015533,  0.009558  , -0.03660792,
#          0.03212324,  0.02074495, -0.01172236, -0.01358556, -0.04511023],
#        [ 0.03044024,  0.02006564,  0.00015533,  0.009558  , -0.03660792,
#          0.03212324,  0.02074495, -0.01172236, -0.01358556, -0.04511023],
#        [ 0.03044024,  0.02006564,  0.00015533,  0.009558  , -0.03660792,
#          0.03212324,  0.02074495, -0.01172236, -0.01358556, -0.04511023],
#        [-0.02508702,  0.01603602, -0.04701871, -0.0139125 , -0.00636628,
#          0.02163669,  0.01651229,  0.01357988, -0.00096762, -0.01999525],
#        [-0.04091221,  0.03472464, -0.01130644,  0.0182649 ,  0.00739504,
#         -0.04004062,  0.04716447, -0.03073124,  0.00784934, -0.02733555],
#        [-0.02141132,  0.00792418, -0.0459176 , -0.01434652, -0.02570109,
#          0.03223789,  0.00888991,  0.0345226 , -0.03853131, -0.03417619],
#        [-0.04122189,  0.02261614, -0.00722284, -0.02436062,  0.01109809,
#          0.00863735, -0.01335945,  0.03298558, -0.02983972,  0.00294145]],
#       dtype=float32)
